# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils import get_player_data

import pickle

# %%
data = get_player_data.extract()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\voyno\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# Cooper Kupp
# Link: <selenium.webdriver.remote.webelement.WebElement (session="03af82fb04ee3d4793e41bfaaf4c96e1", element="b5371202-cc57-4c3e-ae93-f9cb73460ca2")>
# Player card: <selenium.webdriver.remote.webelement.WebElement (session="03af82fb04ee3d4793e41bfaaf4c96e1", element="f5922efe-8967-446b-adb3-f264d92e9d61")>
# New window: CDwindow-FCC35C0B66CBCCDE61F8033B397D1CB8
# Base window: CDwindow-7B7BDE029A75A1CD32630A69256955DB
# Found the following data tables:
# 0 <selenium.webdriver.remote.webelement.WebElement (session="03af82fb04ee3d4793e41bfaaf4c96e1", element="d6a21591-72ca-4333-ae73-29b15e49a728")>
# ...

# %%
with open('data/game_level.pkl', 'wb') as f:
    pickle.dump(data, f)
