# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import get_player_data

# %%
df = get_player_data.etl()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [C:\Users\voyno\.wdm\drivers\chromedriver\win32\101.0.4951.41\chromedriver.exe] found in cache

# %%
df.head()
# Out:
#             PLAYER TYPE ACTION      C/A   YDS  TD INT  CAR   YDS  TD  REC  \
# 0      Cooper Kupp  LAR     WR      0/1     0   0   0    4    18   0  145
# 1       Josh Allen  Buf     QB  409/646  4407  36  15  122   763   6    0
# 2   Justin Herbert  LAC     QB  443/672  5014  38  15   63   302   3    0
# 3        Tom Brady   TB     QB  485/719  5316  43  12   28    81   2    0
# 4  Jonathan Taylor  Ind     RB      0/0     0   0   0  332  1811  18   40
#
#     YDS  TD  TAR 2PC FUML TD    FPTS   AVG
# 0  1947  16  191   0    0  0   439.5  25.9
# 1     0   0    0   0    3  0  402.58  23.7
# 2     0   0    0   0    1  0  380.76  22.4
# 3     0   0    0   0    3  0  374.74  22.0
# 4   360   2   51   0    2  0   373.1  21.9

# %%
lowercase_col_mapper = {col: col.lower() for col in df.columns}
rename_mapper = {
    "type": "team",
    "action": "position"
}

# lowercase col names
df.rename(
    lowercase_col_mapper, 
    axis=1, 
    inplace=True)

# updating team, position col names
df.rename(
    rename_mapper, 
    axis=1, 
    inplace=True)

df.head()
# Out:
#             player team position      c/a   yds  td int  car   yds  td  rec  \
# 0      Cooper Kupp  LAR       WR      0/1     0   0   0    4    18   0  145
# 1       Josh Allen  Buf       QB  409/646  4407  36  15  122   763   6    0
# 2   Justin Herbert  LAC       QB  443/672  5014  38  15   63   302   3    0
# 3        Tom Brady   TB       QB  485/719  5316  43  12   28    81   2    0
# 4  Jonathan Taylor  Ind       RB      0/0     0   0   0  332  1811  18   40
#
#     yds  td  tar 2pc fuml td    fpts   avg
# 0  1947  16  191   0    0  0   439.5  25.9
# 1     0   0    0   0    3  0  402.58  23.7
# 2     0   0    0   0    1  0  380.76  22.4
# 3     0   0    0   0    3  0  374.74  22.0
# 4   360   2   51   0    2  0   373.1  21.9

# %%
df.to_csv('data/player_stats_yearly.csv', index=False)
